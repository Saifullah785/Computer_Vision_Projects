# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/Computer_Vision_Projects/blob/main/Project_01_Image_Classification_with_MobileNetV2/Project_01_Image_Classification_with_MobileNetV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries for image classification and display.
import tensorflow as tf
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# %%
# Initialize MobileNetV2 model with pre-trained ImageNet weights.
model = MobileNetV2(weights='imagenet')
# Out:
# ...
# 14536120/14536120 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Load, preprocess, and predict the class of a single image.
img_path = "/content/drive/MyDrive/cat.jpg"
img = image.load_img(img_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array = preprocess_input(img_array)

predictions = model.predict(img_array)

decoded_predictions = decode_predictions(predictions, top=3)[0]

for i, (imagenet_id, label, score) in enumerate(decoded_predictions):
    print(f"{i + 1}. {label}: {score * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# 1. tabby: 44.97%
# 2. tiger_cat: 21.85%
# 3. Egyptian_cat: 18.07%

# %% [markdown]
# # **Functional Code**

# %%
# Define a function to predict image class, display the image, and print top predictions.
def predict_image_class(img_path):

  img = image.load_img(img_path, target_size=(224, 224))
  img_array = image.img_to_array(img)
  img_array = np.expand_dims(img_array, axis=0)
  img_array = preprocess_input(img_array)

  predictions = model.predict(img_array)

  decoded_predictions = decode_predictions(predictions, top=5)[0]

  plt.imshow(img)
  plt.axis('off')
  plt.show()

  for i, (imagenet_id, label, score) in enumerate(decoded_predictions):
    print(f"{i + 1}. {label}: {score * 100:.2f}%")


img_path = "/content/drive/MyDrive/aug/_0_1076.png"
predict_image_class(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1. Egyptian_cat: 39.93%
# 2. tabby: 18.85%
# 3. lynx: 12.02%
# 4. tiger_cat: 8.69%
# 5. Siamese_cat: 1.28%

# %%
# Predict class for another augmented image.

img_path = "/content/drive/MyDrive/aug/_0_1815.png"
predict_image_class(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1. tabby: 14.42%
# 2. lynx: 12.62%
# 3. tiger_cat: 12.35%
# 4. Egyptian_cat: 7.40%
# 5. carton: 7.02%

# %%
# Predict class for an image of a bird.
img_path = "/content/dragon bird.jpg"
predict_image_class(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1. hen: 31.38%
# 2. coucal: 16.17%
# 3. partridge: 7.35%
# 4. ruffed_grouse: 2.76%
# 5. cock: 2.71%
